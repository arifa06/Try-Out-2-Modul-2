# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# dataset
khd = pd.read_csv('kc_house_data.csv')
khd.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
khd.shape
# Out:
# (21597, 21)

# %%
khd.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
khd.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
khd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
khd.isna().values.any()
# Out:
# False

# %%
khd.duplicated().value_counts()
# Out:
# False    21597
# dtype: int64

# %%
khd.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007547      0.234292      3.409825
# ...

# %%
khd.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.002727  0.266398 -0.006834   0.063744     0.103854  0.021632
# view           0.011536  0.397370  0.080008   0.188386     0.284709  0.074900
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %% [markdown]
# SOAL No. 1

# %%
# 'Price'
prc = khd['price']
pd.DataFrame(prc).describe()
# Out:
#               price
# count  2.159700e+04
# mean   5.402966e+05
# std    3.673681e+05
# min    7.800000e+04
# 25%    3.220000e+05
# 50%    4.500000e+05
# 75%    6.450000e+05
# max    7.700000e+06

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,6))
sns.histplot(prc, bins=50, color='blue', label='Price')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Price Histogram')
plt.legend(loc=0)
plt.grid(True)
plt.show()

# %%
# 'Grade'
grd = khd['grade']
pd.DataFrame(grd).describe()
# Out:
#               grade
# count  21597.000000
# mean       7.657915
# std        1.173200
# min        3.000000
# 25%        7.000000
# 50%        7.000000
# 75%        8.000000
# max       13.000000

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,6))
sns.histplot(grd, bins=10, color='red', label='Grade')
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.title('Grade')
plt.legend(loc=0)
plt.grid(True)
plt.show()

# %% [markdown]
# SOAL No. 2

# %%
q1 = khd['sqft_living'].quantile(0.25)
q3 = khd['sqft_living'].quantile(0.75)

iqr = q3-q1

lower = q1-1.5*iqr
upper = q3+1.5*iqr

print('Lower Bound :', lower)
print('Upper Bound :', upper)
# Out:
# Lower Bound : -250.0
# Upper Bound : 4230.0

# %%
outliers = khd[(khd['sqft_living']>upper) | (khd['sqft_living']<lower)]
outliers.head()
# Out:
#              id        date      price  bedrooms  bathrooms  sqft_living  \
# 5    7237550310   5/12/2014  1230000.0         4       4.50         5420
# 70   1525059190   9/12/2014  1040000.0         5       3.25         4770
# 115  3626039325  11/21/2014   740500.0         3       3.50         4380
# 153  7855801670    4/1/2015  2250000.0         4       3.25         5180
# 239  5152100060   5/29/2014   472000.0         6       2.50         4410
#
#      sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 5      101930     1.0           0     0  ...     11        3890
# 70      50094     1.0           0     0  ...     11        3070
# 115      6350     2.0           0     0  ...      8        2780
# 153     19850     2.0           0     3  ...     12        3540
# 239     14034     1.0           0     2  ...      9        2350
#
#      sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
plt.figure(figsize=(8,6))
sns.boxplot(data=khd, x=khd['sqft_living'])
plt.title('sqft_living Boxplot')
plt.xlabel('sqft_living')
plt.grid(True)
plt.show()

# %% [markdown]
# Soal No. 3

# %%
# 'yr_built'
blt = khd['yr_built']
pd.DataFrame(blt).describe()
# Out:
#            yr_built
# count  21597.000000
# mean    1970.999676
# std       29.375234
# min     1900.000000
# 25%     1951.000000
# 50%     1975.000000
# 75%     1997.000000
# max     2015.000000

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,6))
sns.histplot(blt, bins=20, color='orange', label='yr_built')
plt.xlabel('yr_built')
plt.ylabel('Frequency')
plt.title('yr_built')
plt.legend(loc=0)
plt.grid(True)
plt.show()

# %% [markdown]
# SOAL No. 4

# %%
cor_khd = khd[['grade', 'sqft_lot', 'condition', 'price']].corr()
cor_khd.set_index('price')
# Out:
#              grade  sqft_lot  condition
# price
# 0.667951  1.000000  0.114731  -0.146896
# 0.089876  0.114731  1.000000  -0.008830
# 0.036056 -0.146896 -0.008830   1.000000
# 1.000000  0.667951  0.089876   0.036056

# %% [markdown]
# SOAL No. 5

# %%
cprice = khd[khd['price'] > khd['price'].mean()]
cprice.head()
# Out:
#             id       date      price  bedrooms  bathrooms  sqft_living  \
# 3   2487200875  12/9/2014   604000.0         4       3.00         1960
# 5   7237550310  5/12/2014  1230000.0         4       4.50         5420
# 10  1736800520   4/3/2015   662500.0         3       2.50         3560
# 15  9297300055  1/24/2015   650000.0         4       3.00         2950
# 21  2524049179  8/26/2014  2000000.0         3       2.75         3050
#
#     sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 3       5000     1.0           0     0  ...      7        1050            910
# 5     101930     1.0           0     0  ...     11        3890           1530
# 10      9796     1.0           0     0  ...      8        1860           1700
# 15      5000     2.0           0     3  ...      9        1980            970
# 21     44867     1.0           0     4  ...      9        2330            720
#
# ...

# %%
pd.DataFrame(cprice[['price','zipcode']]).head()
# Out:
#         price  zipcode
# 3    604000.0    98136
# 5   1230000.0    98053
# 10   662500.0    98007
# 15   650000.0    98126
# 21  2000000.0    98040

# %%
plt.style.use('seaborn')
plt.figure(figsize=(8,6))
sns.barplot(x= cprice['zipcode'].head(5), y=cprice['price'].head(5))
plt.xlabel('Zipcodee')
plt.ylabel('Price')
plt.title('Zipcode with The Highest Price')
plt.grid(True)
plt.show()
